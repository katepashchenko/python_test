# %% [markdown]
# <a href="https://colab.research.google.com/github/katepashchenko/python_test/blob/main/%D0%9A%D0%BE%D0%BF%D1%96%D1%8F_%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D0%BD%D0%B8%D0%BA%D0%B0_%22hw_9_3_%D0%A6%D0%B8%D0%BA%D0%BB_while_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до теми "Цикл while"

# %% [markdown]
# 1. **Лічильник до заданого числа.**
#    Завдання:
#      - Створіть цикл `while`, щоб він лічив від 1 до заданого числа в змінній `limit` (включно).
#      - Виведіть кожне число, яке проходить лічильник, на екран.
#      - В кінці виведіть повідомлення "Кінець розрахунку!".

# %%
limit = 9  # Задане число

# %%
i = 1
while i <= limit:
  print (i)
  i += 1
print ("Кінець розрахунку!")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Кінець розрахунку!

# %% [markdown]
# 2. **Пошук першого парного числа.** Завдання:
#      - Створіть цикл `while`, щоб знайти перше парне число після заданого числа `start`.
#      - Знайдіть та виведіть перше парне число.

# %%
start = 7  # Задане число

# %%
while start % 2 != 0:
    start += 1

print(start)
# Out:
# 8

# %% [markdown]
# 3. **Обчислення факторіалу.**
#   Факторіал числа - це добуток всіх натуральних чисел від 1 до цього числа включно. Наприклад, факторіал числа 5 (позначається як 5!) дорівнює `1 * 2 * 3 * 4 * 5 = 120`.
#
#   Завдання:
#       - Обчисліть факторіал заданого числа, використовуючи цикл `while`.
#       - Задайте деяке число для обчислення факторіалу у змінній `num`.
#       - Виведіть обчислений факторіал на екран.

# %%
num = 8

factorial = 1

while num > 1:
    factorial *= num
    num -= 1

print(factorial)
# Out:
# 40320
